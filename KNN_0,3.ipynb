# %%
#ANDMETE SAAMINE

#laeme alla vajalikud moodulid
import numpy as np
import pandas as pd

#laeme alla andmed csv-st, mille nimi on spotify_dataset
andmed = pd.read_csv("spotify_dataset.csv") 

#võtame andmetest vaid need tulbad, mida kasutame koodis
uus = andmed[["Highest Charting Position", "Number of Times Charted", "Streams", "Artist Followers", "Popularity", "Danceability", "Energy", "Loudness", "Speechiness", "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]]

#võtame ära read, kus on tühikud ehk kus andmeid pole
uus = uus[(uus["Highest Charting Position"]!=" ") & (uus["Number of Times Charted"]!=" ") & (uus["Artist Followers"]!=" ") & (uus["Popularity"]!=" ") & (uus["Danceability"]!=" ")& (uus["Energy"]!=" ")& (uus["Loudness"]!=" ") & (uus["Speechiness"]!=" ") & (uus["Acousticness"]!=" ")  & (uus[ "Liveness"]!=" ") & (uus["Tempo"]!=" ") & (uus["Duration (ms)"]!=" ") & (uus["Valence"]!=" ")] 

#võtame streamide arvus komad vahepealt ära
uus["Streams"] = uus['Streams'].str.replace(",","") 

#teeme kõik väärtused floatiks ehk komadega arvuks
uus = uus.astype(float)

# %%
#TREENIMISE JA TESTMISE GRUPPIDE TEGEMINE

#impordime tegevuseks vajaliku mooduli
from sklearn.model_selection import train_test_split

#X väärtuseks paneme kõik tulbad peale "Streams", mida kasutatakse ennustuse tegemiseks
X = uus[["Highest Charting Position", "Number of Times Charted", "Artist Followers", "Popularity", "Danceability", "Energy", "Loudness", "Speechiness", "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]] # Mean squarred error (MSE): 7609495144579.66 Coefficient of determination (R2): 0.07 

# y väärtuseks tuleb ennustatav suurus
y = uus[["Streams"]]

#jaotame anded X ja y treenimise ja testmise gruppidesse
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) 

#kuvame treenimise grupi streamid
y_train
# Out:
#         Streams
# 644   5802508.0
# 428   9872084.0
# 397   5655879.0
# 1107  4567732.0
# 352   5252767.0
# ...         ...
# 721   5698275.0
# 914   4982232.0
# 1105  4627942.0
# 237   6731106.0
# 1070  4543863.0
#
# [1081 rows x 1 columns]

# %%
#kuvame treenimise gruppide suuruse
y_train.shape, X_train.shape
# Out:
# ((1081, 1), (1081, 13))

# %%
#kuvame testimise gruppide suuruse
X_test.shape, y_test.shape
# Out:
# ((464, 13), (464, 1))

# %%
#TREENING GRUPIGA TREENIMINE

#impordime vajaliku mooduli
from sklearn.neighbors import KNeighborsClassifier

#mooduli treenimine kasutades treening gruppe
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# C:\Users\eliis\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
#        [5093408.],
#        [4390823.],
#        [4851895.],
#        [4790427.],
#        [5093408.],
#        [4727554.],
#        [4874960.],
#        [4522005.],
#        [4661170.],
#        [5048079.],
#        [5449099.],
#        [5255393.],
#        [6142975.],
#        [4527835.],
#        [6384306.],
#        [4624448.],
#        [6384306.],
#        [5231134.],
#        [4737291.],
#        [5424579.],
#        [5056986.],
#        [4685894.],
#        [4847224.],
#        [5004111.],
#        [4470597.],
#        [5082870.],
#        [4729629.],
#        [5026961.],
#        [4874380.],
#        [5119828.],
#        [4609858.],
#        [4884711.],
#        [4352767.],
#        [5238547.],
#        [4371370.],
#        [6374807.],
#        [4367368.],
#        [4664281.],
#        [4957966.],
#        [5068677.],
#        [4593309.],
#        [5846760.],
#        [4218201.],
#        [4313625.],
#        [5867746.],
#        [4485060.],
#        [5323062.],
#        [7347891.],
#        [4296154.],
#        [5189427.],
#        [5093408.],
#        [4599408.],
#        [5112180.],
#        [4641393.],
#        [4713873.],
#        [4851895.],
#        [4569978.],
#        [4371370.],
#        [4364166.],
#        [6996402.],
#        [4652583.],
#        [5550390.],
#        [4818039.],
#        [5046418.],
#        [4980744.],
#        [4252898.],
#        [5858768.],
#        [5858768.],
#        [4540781.],
#        [7695566.],
#        [4971559.],
#        [4732343.],
#        [4615520.],
#        [4972518.],
#        [4680447.],
#        [5119828.],
#        [4405338.],
#        [4847224.],
#        [5083648.],
#        [5192813.],
#        [4314080.],
#        [4527742.],
#        [4394195.],
#        [4874380.],
#        [5208787.],
#        [4730891.],
#        [5110064.],
#        [5208787.],
#        [5209372.],
#        [4784580.],
#        [4765672.],
#        [4502853.],
#        [4565400.],
#        [4587573.],
#        [4796365.],
#        [5282490.],
#        [4522005.],
#        [5093408.],
#        [6858466.],
#        [5083648.],
#        [4565400.],
#        [4972518.],
#        [4848222.],
#        [5645966.],
#        [5029858.],
#        [4907925.],
#        [4940701.],
#        [4654587.],
#        [4553544.],
#        [5029979.],
#        [5534361.],
#        [4664281.],
#        [4813796.],
#        [5013019.],
#        [4723116.],
#        [5867746.],
#        [4874960.],
#        [4352767.],
#        [5527865.],
#        [4723116.],
#        [4967348.],
#        [6462701.],
#        [4980744.],
#        [4906738.],
#        [4998044.],
#        [4585895.],
#        [5013851.],
#        [4901559.]])

# %%
#kuvame streamide tegelikud väärtused
y_test
# Out:
#         Streams
# 1323  4787180.0
# 483   5418816.0
# 641   6404964.0
# 1241  5291167.0
# 1272  5307288.0
# ...         ...
# 454   5094660.0
# 551   4908929.0
# 305   5395181.0
# 1345  5487069.0
# 218   5116589.0
#
# [464 rows x 1 columns]

# %%
#arvutame ennustuse ja tegeliku streamide arvu vahe absoluutväärtuses ja kuvame selle
vahe = abs(y_pred - y_test) 
vahe = list(vahe["Streams"])
vahe
# Out:
# [110194.0,
#  777423.0,
#  1373119.0,
#  568051.0,
#  747433.0,
#  171978.0,
#  1149219.0,
#  665321.0,
#  437958.0,
#  5005785.0,
#  1608621.0,
#  1693972.0,
#  1096141.0,
#  132422.0,
#  561326.0,
#  435476.0,
#  773729.0,
#  2785094.0,
#  833954.0,
#  455564.0,
#  970363.0,
#  190924.0,
#  5891418.0,
#  2396728.0,
#  2122940.0,
#  671139.0,
#  716837.0,
#  1363406.0,
#  1789357.0,
#  2300986.0,
#  23962.0,
#  1800101.0,
#  2592062.0,
#  599106.0,
#  8698542.0,
#  8007262.0,
#  506631.0,
#  234169.0,
#  634142.0,
#  583529.0,
#  705102.0,
#  366017.0,
#  555517.0,
#  922231.0,
#  782222.0,
#  317075.0,
#  338687.0,
#  2375740.0,
#  37297.0,
#  1634420.0,
#  6020402.0,
#  2646711.0,
#  4045797.0,
#  469867.0,
#  6351.0,
#  374745.0,
#  41719.0,
#  559325.0,
#  1813938.0,
#  547890.0,
#  460369.0,
#  279899.0,
#  517325.0,
#  9801420.0,
#  351557.0,
#  2656714.0,
#  260224.0,
#  1334376.0,
#  910444.0,
#  348073.0,
#  2315366.0,
#  872195.0,
#  197364.0,
#  352837.0,
#  769712.0,
#  609991.0,
#  242682.0,
#  1962363.0,
#  356281.0,
#  496407.0,
#  355185.0,
#  510913.0,
#  5971697.0,
#  324583.0,
#  804050.0,
#  2234189.0,
#  1083179.0,
#  3031859.0,
#  176427.0,
#  3032471.0,
#  4578533.0,
#  1125719.0,
#  1199692.0,
#  7019102.0,
#  170603.0,
#  2980059.0,
#  177376.0,
#  938099.0,
#  326754.0,
#  120646.0,
#  23828871.0,
#  175404.0,
#  261864.0,
#  528237.0,
#  85633.0,
#  187922.0,
#  89115.0,
#  809286.0,
#  473218.0,
#  215030.0]

# %%
#arvutame vahede absoluutväärtused kokku
vahe_kokku = 0
for i in vahe:
    vahe_kokku += i
vahe_kokku
# Out:
# 692211693.0

# %%
#kuvame keskmine vahe
keskmine_vahe = vahe_kokku // 464
print("Keskmine vahe on: " + str(keskmine_vahe))
# Out:
# Keskmine vahe on: 1491835.0

# %%
#TÄPSUSE HINDAMINE

#vaatame igat arvutatud vahet ja jagame vastavalt suuruse järgi selle gruppidesse, et näha kui täpselt ennustati streamide arvu
loendur1 = 0 
loendur2 = 0 
loendur3 = 0 
loendur4 = 0 
loendur5 = 0 
loendur6 = 0 
loendur7 = 0 
loendur8 = 0 
loendur9 = 0 
loendur10 = 0 
loendur11 = 0
loendur12 = 0
loendur13 = 0
loendur14 = 0
loendur15 = 0
loendur16 = 0
loendur17 = 0
loendur18 = 0
loendur19 = 0
loendur = 0

for i in vahe:
    if float(i) < 10000:
        loendur1 += 1
    elif i < 100000:
        loendur2 += 1
    elif i < 200000:
        loendur3 += 1    
    elif i < 300000:
        loendur4 += 1
    elif i < 400000:
        loendur5 += 1
    elif i < 500000:
        loendur6 += 1
    elif i < 600000:
        loendur7 += 1
    elif i < 700000:
        loendur8 += 1
    elif i < 800000:
        loendur9 += 1
    elif i < 900000:
        loendur10 += 1
    elif i < 1000000:
        loendur11 += 1
    elif i < 2000000:
        loendur12 += 1
    elif i < 3000000:
        loendur13 += 1
    elif i < 4000000:
        loendur14 += 1
    elif i < 5000000:
        loendur15 += 1
    elif i < 6000000:
        loendur16 += 1
    elif i < 7000000:
        loendur17 += 1
    elif i < 8000000:
        loendur18 += 1
    elif i < 9000000:
        loendur19 += 1
    elif i >= 900000:
        loendur += 1

#kuvame mitu ennustust olid erinevates vahemikes
print("Vahe väärtus vahemikus 0-10000: ", str(loendur1))
print("Vahe väärtus vahemikus 10000-100000: ", str(loendur2))
print("Vahe väärtus vahemikus 100000-200000: ", str(loendur3))
print("Vahe väärtus vahemikus 200000-300000: ", str(loendur4))
print("Vahe väärtus vahemikus 300000-400000: ", str(loendur5))
print("Vahe väärtus vahemikus 400000-500000: ", str(loendur6))
print("Vahe väärtus vahemikus 500000-600000: ", str(loendur7))
print("Vahe väärtus vahemikus 600000-700000: ", str(loendur8))
print("Vahe väärtus vahemikus 700000-800000: ", str(loendur9))
print("Vahe väärtus vahemikus 800000-900000: ", str(loendur10))
print("Vahe väärtus vahemikus 900000-1000000: ", str(loendur11))
print("Vahe väärtus vahemikus 1000000-2000000: ", str(loendur12))
print("Vahe väärtus vahemikus 2000000-3000000: ", str(loendur13))
print("Vahe väärtus vahemikus 3000000-4000000: ", str(loendur14))
print("Vahe väärtus vahemikus 4000000-5000000: ", str(loendur15))
print("Vahe väärtus vahemikus 5000000-6000000: ", str(loendur16))
print("Vahe väärtus vahemikus 6000000-7000000: ", str(loendur17))
print("Vahe väärtus vahemikus 7000000-8000000: ", str(loendur18))
print("Vahe väärtus vahemikus 8000000-9000000: ", str(loendur19))
print("Vahe väärtus vahemikus 9000000+: ", str(loendur))
# Out:
# Vahe väärtus vahemikus 0-10000:  8
# Vahe väärtus vahemikus 10000-100000:  33
# Vahe väärtus vahemikus 100000-200000:  49
# Vahe väärtus vahemikus 200000-300000:  38
# Vahe väärtus vahemikus 300000-400000:  36
# Vahe väärtus vahemikus 400000-500000:  30
# Vahe väärtus vahemikus 500000-600000:  38
# Vahe väärtus vahemikus 600000-700000:  22
# Vahe väärtus vahemikus 700000-800000:  19
# Vahe väärtus vahemikus 800000-900000:  13
# Vahe väärtus vahemikus 900000-1000000:  13
# Vahe väärtus vahemikus 1000000-2000000:  62
# Vahe väärtus vahemikus 2000000-3000000:  38
# Vahe väärtus vahemikus 3000000-4000000:  22
# Vahe väärtus vahemikus 4000000-5000000:  16
# Vahe väärtus vahemikus 5000000-6000000:  9
# Vahe väärtus vahemikus 6000000-7000000:  4
# Vahe väärtus vahemikus 7000000-8000000:  3
# Vahe väärtus vahemikus 8000000-9000000:  3
# Vahe väärtus vahemikus 9000000+:  8

# %%
#kuvame mitu korda oli ennustuse ja tegliku arvu vahe alla 1000
print("Vahe alla 10000 oli: ", str(loendur1))
# Out:
# Vahe alla 10000 oli:  8
