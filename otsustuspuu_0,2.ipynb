# %%
#ANDMETE SAAMINE

#laeme alla vajalikud moodulid
import pandas as pd 
import numpy as np

#laeme alla andmed csv-st, mille nimi on spotify_dataset
andmed = pd.read_csv("spotify_dataset.csv")

#võtame andmetest vaid need tulbad, mida kasutame koodis
uus = andmed[["Highest Charting Position", "Number of Times Charted", "Streams", "Artist Followers", "Popularity", "Danceability", "Energy", "Loudness", "Speechiness", "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]]

#võtame ära read, kus on tühikud ehk kus andmeid pole
uus = uus[(uus["Highest Charting Position"]!=" ") & (uus["Number of Times Charted"]!=" ") & (uus["Artist Followers"]!=" ") & (uus["Popularity"]!=" ") & (uus["Danceability"]!=" ")& (uus["Energy"]!=" ")& (uus["Loudness"]!=" ") & (uus["Speechiness"]!=" ") & (uus["Acousticness"]!=" ")  & (uus[ "Liveness"]!=" ") & (uus["Tempo"]!=" ") & (uus["Duration (ms)"]!=" ") & (uus["Valence"]!=" ")] 

#võtame streamide arvus komad vahepealt ära
uus["Streams"] = uus['Streams'].str.replace(",","")

#teeme kõik väärtused floatiks ehk komadega arvuks
uus = uus.astype(float)

# %%
#TREENIMISE JA TESTMISE GRUPPIDE TEGEMINE

#impordime tegevuseks vajaliku mooduli
from sklearn.model_selection import train_test_split

#X väärtuseks paneme kõik tulbad peale "Streams", mida kasutatakse ennustuse tegemiseks
X = uus[["Highest Charting Position", "Number of Times Charted", "Artist Followers", "Popularity", "Danceability", "Energy", "Loudness", "Speechiness", "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]] # Mean squarred error (MSE): 7609495144579.66 Coefficient of determination (R2): 0.07 

# y väärtuseks tuleb ennustatav suurus
y = uus[["Streams"]]

#jaotame anded X ja y treenimise ja testmise gruppidesse
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) 

#kuvame treenimise grupi streamid
y_train
# Out:
#         Streams
# 402   5198209.0
# 964   4351784.0
# 1309  5411302.0
# 1138  6069544.0
# 121   6242863.0
# ...         ...
# 721   5698275.0
# 914   4982232.0
# 1105  4627942.0
# 237   6731106.0
# 1070  4543863.0
#
# [1236 rows x 1 columns]

# %%
#kuvame treenimise gruppide suuruse
y_train.shape, X_train.shape
# Out:
# ((1236, 1), (1236, 13))

# %%
#kuvame testimise gruppide suuruse
X_test.shape, y_test.shape
# Out:
# ((309, 13), (309, 1))

# %%
#TREENING GRUPIGA TREENIMINE

#impordime vajaliku mooduli
from sklearn import tree

#mooduli treenimine kasutades treening gruppe
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#ENNUSTAME STREAMIDE ARVU
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(309,1) 
#kuvame ennustused
y_pred
# Out:
# array([[ 8387899.],
#        [ 6635109.],
#        [ 5137482.],
#        [ 9325928.],
#        [11756283.],
#        [ 5411302.],
#        [ 7917707.],
#        [ 4463865.],
#        [ 5118004.],
#        [ 5201714.],
#        [ 5066711.],
#        [ 6108393.],
#        [ 5063181.],
#        [ 4946613.],
#        [ 4957966.],
#        [ 6464206.],
#        [ 5846760.],
#        [ 5652272.],
#        [ 4805366.],
#        [ 4813796.],
#        [ 5204120.],
#        [ 5060764.],
#        [ 8355036.],
#        [ 5392334.],
#        [ 5379704.],
# 1550  4676857.0
# 1456  5823422.0
#
# [309 rows x 1 columns]

# %%
#arvutame ennustuse ja tegeliku streamide arvu vahe absoluutväärtuses ja kuvame selle
vahe = abs(y_pred - y_test) 
vahe = list(vahe["Streams"])
vahe
# Out:
# [3600719.0,
#  1216293.0,
#  1267482.0,
#  4034761.0,
#  6448995.0,
#  441640.0,
#  2230726.0,
#  742237.0,
#  142284.0,
#  122127.0,
#  80412.0,
#  2341164.0,
#  1588244.0,
#  78993.0,
#  74764.0,
#  1291028.0,
#  1632858.0,
#  1056834.0,
#  5036632.0,
#  1886099.0,
#  618146.0,
#  3978754.0,
#  263282.0,
#  382155.0,
#  396812.0,
#  1751519.0,
#  801578.0,
#  571952.0,
#  1015087.0,
#  1416355.0,
#  679783.0,
#  4944032.0,
#  1816434.0,
#  2365530.0,
#  3331366.0,
#  2101843.0,
#  30673.0,
#  852854.0,
#  527250.0,
#  221219.0,
#  358314.0,
#  383878.0,
#  527925.0,
#  588501.0,
#  687685.0,
#  810497.0,
#  88857.0,
#  119574.0,
#  1671124.0,
#  833222.0,
#  2627049.0,
#  444218.0,
#  8013744.0,
#  1027847.0,
#  470956.0,
#  3569572.0,
#  28904.0,
#  802387.0,
#  583905.0,
#  179109.0,
#  2787657.0,
#  1733405.0,
#  306550.0,
#  574079.0,
#  1134602.0,
#  966123.0,
#  1538135.0,
#  6009666.0,
#  1734359.0,
#  864279.0,
#  4062924.0,
#  648278.0,
#  1226916.0,
#  1406946.0,
#  617063.0,
#  551684.0,
#  377461.0,
#  1026415.0,
#  36583.0,
#  2250034.0,
#  229789.0,
#  15992.0,
#  4016661.0,
#  2581.0,
#  56351.0,
#  816380.0,
#  241557.0,
#  2679918.0,
#  279269.0,
#  95396.0,
#  1241012.0,
#  837239.0,
#  6035901.0,
#  116715.0,
#  712786.0,
#  1091479.0,
#  334349.0,
#  3023644.0,
#  4193159.0,
#  1951628.0,
#  3803782.0,
#  924433.0,
#  376770.0,
#  411452.0,
#  447488.0,
#  4372145.0,
#  466525.0,
#  12824.0,
#  11193922.0,
#  2081347.0,
#  363576.0,
#  1045331.0,
#  539532.0,
#  382987.0,
#  427309.0,
#  2178330.0,
#  4205935.0,
#  1157434.0,
#  814454.0,
#  5128251.0,
#  876791.0,
#  1917091.0,
#  168002.0,
#  413304.0,
#  740028.0,
#  243827.0,
#  137515.0,
#  361871.0,
#  2698930.0,
#  425550.0,
#  894383.0,
#  2065285.0,
#  532689.0,
#  610182.0,
#  1363685.0,
#  200521.0,
#  4986460.0,
#  1127686.0,
#  1505573.0,
#  2315493.0,
#  341946.0,
#  130479.0,
#  1417191.0,
#  519909.0,
#  842371.0,
#  2461176.0,
#  312128.0,
#  1178001.0,
#  18480886.0,
#  842098.0,
#  310329.0,
#  1243412.0,
#  166354.0,
#  10003998.0,
#  138873.0,
#  2631960.0,
#  336803.0,
#  990365.0,
#  2081293.0,
#  156354.0,
#  1454173.0,
#  485922.0,
#  289701.0,
#  1101023.0,
#  435480.0,
#  259275.0,
#  11895185.0,
#  909165.0,
#  106192.0,
#  317232.0,
#  772924.0,
#  922732.0,
#  999379.0,
#  4951.0,
#  32558229.0,
#  294277.0,
#  1772045.0,
#  1394613.0,
#  54227.0,
#  47943.0,
#  174091.0,
#  81471.0,
#  1300064.0,
#  223253.0,
#  1443322.0,
#  5283458.0,
#  2109302.0,
#  517619.0,
#  970243.0,
#  1442575.0,
#  138470.0,
#  1542315.0,
#  1438593.0,
#  993283.0,
#  468751.0,
#  894409.0,
#  839472.0,
#  441724.0,
#  127051.0,
#  473830.0,
#  73798.0,
#  13582.0,
#  2435740.0,
#  5627990.0,
#  202450.0,
#  209341.0,
#  4132102.0,
#  32888.0,
#  857335.0,
#  6853167.0,
#  237337.0,
#  3937344.0,
#  2525150.0,
#  1252288.0,
#  824754.0,
#  1168888.0,
#  947911.0,
#  377038.0,
#  1310525.0,
#  912664.0,
#  600116.0,
#  5168714.0,
#  4089573.0,
#  67088.0,
#  577586.0,
#  977295.0,
#  1419976.0,
#  167730.0,
#  89517.0,
#  2320637.0,
#  7739248.0,
#  624032.0,
#  151336.0,
#  1443340.0,
#  172640.0,
#  793508.0,
#  883270.0,
#  769545.0,
#  148229.0,
#  2339722.0,
#  104088.0,
#  182564.0,
#  2143015.0,
#  936451.0,
#  241042.0,
#  1392555.0,
#  5576385.0,
#  2656425.0,
#  515644.0,
#  1949400.0,
#  631993.0,
#  9270.0,
#  479899.0,
#  384002.0,
#  508880.0,
#  1986570.0,
#  2133591.0,
#  86229.0,
#  238018.0,
#  1775600.0,
#  911372.0,
#  12394.0,
#  731977.0,
#  238223.0,
#  821237.0,
#  1235278.0,
#  515538.0,
#  829551.0,
#  1783195.0,
#  4337357.0,
#  1136458.0,
#  6026202.0,
#  1680634.0,
#  1042698.0,
#  1389639.0,
#  796980.0,
#  1255246.0,
#  130495.0,
#  516426.0,
#  4493613.0,
#  1096847.0,
#  85437.0,
#  2716972.0,
#  960131.0,
#  3748100.0,
#  12631928.0,
#  1031123.0,
#  367580.0,
#  3709676.0,
#  9448.0,
#  1006474.0,
#  311936.0,
#  645721.0,
#  543349.0,
#  467620.0,
#  3058515.0,
#  450875.0,
#  770349.0,
#  60501.0,
#  1737796.0,
#  329824.0,
#  406328.0,
#  194250.0,
#  11309258.0,
#  686793.0,
#  408225.0,
#  210364.0,
#  424783.0,
#  646078.0]

# %%
#arvutame vahede absoluutväärtused kokku
vahe_kokku = 0
for i in vahe:
    vahe_kokku += i
vahe_kokku
# Out:
# 498823541.0

# %%
#kuvame keskmine vahe
keskmine_vahe = vahe_kokku // 309
print("Keskmine vahe on: " + str(keskmine_vahe))
# Out:
# Keskmine vahe on: 1614315.0

# %%
#TÄPSUSE HINDAMINE

#vaatame igat arvutatud vahet ja jagame vastavalt suuruse järgi selle gruppidesse, et näha kui täpselt ennustati streamide arvu
loendur1 = 0 
loendur2 = 0 
loendur3 = 0 
loendur4 = 0 
loendur5 = 0 
loendur6 = 0 
loendur7 = 0 
loendur8 = 0 
loendur9 = 0 
loendur10 = 0 
loendur11 = 0
loendur12 = 0
loendur13 = 0
loendur14 = 0
loendur15 = 0
loendur16 = 0
loendur17 = 0
loendur18 = 0
loendur19 = 0
loendur = 0

for i in vahe:
    if i < 10000:
        loendur1 += 1
    elif i < 100000:
        loendur2 += 1
    elif i < 200000:
        loendur3 += 1    
    elif i < 300000:
        loendur4 += 1
    elif i < 400000:
        loendur5 += 1
    elif i < 500000:
        loendur6 += 1
    elif i < 600000:
        loendur7 += 1
    elif i < 700000:
        loendur8 += 1
    elif i < 800000:
        loendur9 += 1
    elif i < 900000:
        loendur10 += 1
    elif i < 1000000:
        loendur11 += 1
    elif i < 2000000:
        loendur12 += 1
    elif i < 3000000:
        loendur13 += 1
    elif i < 4000000:
        loendur14 += 1
    elif i < 5000000:
        loendur15 += 1
    elif i < 6000000:
        loendur16 += 1
    elif i < 7000000:
        loendur17 += 1
    elif i < 8000000:
        loendur18 += 1
    elif i < 9000000:
        loendur19 += 1
    elif i >= 900000:
        loendur += 1
        
#kuvame mitu ennustust olid erinevates vahemikes
print("Vahe väärtus vahemikus 0-10000: ", str(loendur1))
print("Vahe väärtus vahemikus 10000-100000: ", str(loendur2))
print("Vahe väärtus vahemikus 100000-200000: ", str(loendur3))
print("Vahe väärtus vahemikus 200000-300000: ", str(loendur4))
print("Vahe väärtus vahemikus 300000-400000: ", str(loendur5))
print("Vahe väärtus vahemikus 400000-500000: ", str(loendur6))
print("Vahe väärtus vahemikus 500000-600000: ", str(loendur7))
print("Vahe väärtus vahemikus 600000-700000: ", str(loendur8))
print("Vahe väärtus vahemikus 700000-800000: ", str(loendur9))
print("Vahe väärtus vahemikus 800000-900000: ", str(loendur10))
print("Vahe väärtus vahemikus 900000-1000000: ", str(loendur11))
print("Vahe väärtus vahemikus 1000000-2000000: ", str(loendur12))
print("Vahe väärtus vahemikus 2000000-3000000: ", str(loendur13))
print("Vahe väärtus vahemikus 3000000-4000000: ", str(loendur14))
print("Vahe väärtus vahemikus 4000000-5000000: ", str(loendur15))
print("Vahe väärtus vahemikus 5000000-6000000: ", str(loendur16))
print("Vahe väärtus vahemikus 6000000-7000000: ", str(loendur17))
print("Vahe väärtus vahemikus 7000000-8000000: ", str(loendur18))
print("Vahe väärtus vahemikus 8000000-9000000: ", str(loendur19))
print("Vahe väärtus vahemikus 9000000+: ", str(loendur))
# Out:
# Vahe väärtus vahemikus 0-10000:  4
# Vahe väärtus vahemikus 10000-100000:  23
# Vahe väärtus vahemikus 100000-200000:  23
# Vahe väärtus vahemikus 200000-300000:  18
# Vahe väärtus vahemikus 300000-400000:  21
# Vahe väärtus vahemikus 400000-500000:  20
# Vahe väärtus vahemikus 500000-600000:  17
# Vahe väärtus vahemikus 600000-700000:  12
# Vahe väärtus vahemikus 700000-800000:  9
# Vahe väärtus vahemikus 800000-900000:  20
# Vahe väärtus vahemikus 900000-1000000:  14
# Vahe väärtus vahemikus 1000000-2000000:  61
# Vahe väärtus vahemikus 2000000-3000000:  25
# Vahe väärtus vahemikus 3000000-4000000:  10
# Vahe väärtus vahemikus 4000000-5000000:  12
# Vahe väärtus vahemikus 5000000-6000000:  6
# Vahe väärtus vahemikus 6000000-7000000:  5
# Vahe väärtus vahemikus 7000000-8000000:  1
# Vahe väärtus vahemikus 8000000-9000000:  1
# Vahe väärtus vahemikus 9000000+:  7

# %%
#kuvame mitu korda oli ennustuse ja tegliku arvu vahe alla 1000
print("Vahe alla 10000 oli: ", str(loendur1))
# Out:
# Vahe alla 10000 oli:  4
