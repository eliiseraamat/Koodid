# %%
#ANDMETE SAAMINE

#laeme alla vajalikud moodulid
import pandas as pd 
import numpy as np

#laeme alla andmed csv-st, mille nimi on spotify_dataset
andmed = pd.read_csv("spotify_dataset.csv") 

#võtame andmetest vaid need tulbad, mida kasutame koodis
uus = andmed[["Highest Charting Position", "Number of Times Charted", "Streams", "Artist Followers", "Popularity", "Danceability", "Energy", "Loudness", "Speechiness", "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]] 

#võtame ära read, kus on tühikud ehk kus andmeid pole
uus = uus[(uus["Highest Charting Position"]!=" ") & (uus["Number of Times Charted"]!=" ") & (uus["Artist Followers"]!=" ") & (uus["Popularity"]!=" ") & (uus["Danceability"]!=" ")& (uus["Energy"]!=" ")& (uus["Loudness"]!=" ") & (uus["Speechiness"]!=" ") & (uus["Acousticness"]!=" ")  & (uus[ "Liveness"]!=" ") & (uus["Tempo"]!=" ") & (uus["Duration (ms)"]!=" ") & (uus["Valence"]!=" ")]  

#võtame streamide arvus komad vahepealt ära
uus["Streams"] = uus['Streams'].str.replace(",","") 

#teeme kõik väärtused floatiks ehk komadega arvuks
uus = uus.astype(float)

# %%
#TREENIMISE JA TESTMISE GRUPPIDE TEGEMINE

#impordime tegevuseks vajaliku mooduli
from sklearn.model_selection import train_test_split

#X väärtuseks paneme kõik tulbad peale "Streams", mida kasutatakse ennustuse tegemiseks
X = uus[["Highest Charting Position", "Number of Times Charted", "Artist Followers", "Popularity", "Danceability", "Energy", "Loudness", "Speechiness", "Acousticness", "Liveness", "Tempo", "Duration (ms)", "Valence"]] # Mean squarred error (MSE): 7609495144579.66 Coefficient of determination (R2): 0.07 

# y väärtuseks tuleb ennustatav suurus
y = uus[["Streams"]]

#jaotame anded X ja y treenimise ja testmise gruppidesse
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) 

#kuvame treenimise grupi streamid
y_train
# Out:
#         Streams
# 402   5198209.0
# 964   4351784.0
# 1309  5411302.0
# 1138  6069544.0
# 121   6242863.0
# ...         ...
# 721   5698275.0
# 914   4982232.0
# 1105  4627942.0
# 237   6731106.0
# 1070  4543863.0
#
# [1236 rows x 1 columns]

# %%
#kuvame treenimise gruppide suuruse
y_train.shape, X_train.shape
# Out:
# ((1236, 1), (1236, 13))

# %%
#kuvame testimise gruppide suuruse
X_test.shape, y_test.shape
# Out:
# ((309, 13), (309, 1))

# %%
#TREENING GRUPIGA TREENIMINE

#impordime vajaliku mooduli
from sklearn import linear_model

#mooduli treenimine kasutades treening gruppe
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#ENNUSTAME STREAMIDE ARVU
y_pred = reg.predict(X_test)
y_pred = y_pred.reshape(309,1)
#kuvame ennustused
y_pred
# Out:
# array([[2179671.11278078],
#        [7682075.10371017],
#        [7863728.26471091],
#        [5286431.09779331],
#        [8432884.80203345],
#        [5752012.22470782],
#        [5701125.65072692],
#        [6666874.75821211],
#        [4200986.14601371],
#        [5583261.34112701],
#        [5481288.8790123 ],
#        [8676390.3144893 ],
#        [6753253.04701573],
#        [9147722.96138633],
#        [8523637.12899506],
#        [6149730.02010188],
#        [7383323.2581207 ],
#        [7572275.74775735],
#        [8834369.66074429],
#        [5793159.83416407],
#        [7581844.37493786],
#        [4808093.78516321],
#        [6172643.91061555],
#        [7833663.14336098],
#        [7045939.62328343],
#        [7879943.60039366],
#        [5601426.72788988],
#        [4965590.24626993],
#        [4550495.38886895],
#        [8642395.71302013],
#        [7505208.53580284],
#        [5579587.91497404],
#        [3886966.37419693],
#        [6607988.67636334],
#        [7668963.43062735],
#        [5584992.45369172],
#        [5776318.46969575],
#        [3791675.70986013],
#        [5708782.29060296],
#        [8246146.54998325],
#        [7938568.64203761],
#        [5442098.3774335 ],
#        [6639833.21661625],
#        [6686108.25038148],
#        [5488374.47686413],
#        [7267035.75237889],
#        [4969084.94833052],
#        [6708801.57195863],
#        [5309556.30089306],
#        [6951661.52587315],
#        [8492446.599125  ],
#        [4370651.34965516],
#        [7158536.93767653]])

# %%
#kuvame streamide tegelikud väärtused
y_test
# Out:
#         Streams
# 1323  4787180.0
# 483   5418816.0
# 641   6404964.0
# 1241  5291167.0
# 1272  5307288.0
# ...         ...
# 946   4391666.0
# 809   5226264.0
# 771   5308945.0
# 1550  4676857.0
# 1456  5823422.0
#
# [309 rows x 1 columns]

# %%
#arvutame ennustuse ja tegeliku streamide arvu vahe absoluutväärtuses ja kuvame selle
vahe_kokku = 0
vahe = abs(y_pred - y_test)
vahe = list(vahe["Streams"])
vahe
# Out:
# [2607508.887219217,
#  2263259.1037101736,
#  1458764.2647109134,
#  4735.902206694707,
#  3125596.8020334467,
#  782350.2247078158,
#  14144.6507269172,
#  1460772.7582121082,
#  774733.8539862949,
#  503674.34112700634,
#  494989.8790123034,
#  226833.3144893013,
#  101828.04701573402,
#  4280102.961386332,
#  3640435.128995057,
#  976552.0201018769,
#  96294.74187929556,
#  863169.7477573492,
#  1007628.3392557073,
#  3763393.2837652112,
#  869306.0189716499,
#  2636780.926641614,
#  829399.4124421217,
#  251897.39114229102,
#  2634315.6754392833,
#  425183.7043437138,
#  2203473.171571453,
#  56534.94502397627,
#  380051.98987667356,
#  1078149.224659576,
#  1361782.3431600006,
#  3064361.2832322456,
#  143314.94036501646,
#  895231.8919112915,
#  1613628.1051305681,
#  2317745.9906677036,
#  4085993.2886390835,
#  2169549.155380156,
#  2298609.3623526925,
#  3534154.0841262657,
#  1709551.5663267989,
#  148354.855448436,
#  2100964.5460084025,
#  793766.3466452304,
#  1118893.0153011726,
#  883343.8690645974,
#  3351674.2546955086,
#  362739.2278514216,
#  639387.8885849919,
#  842878.597400927,
#  1284261.8341944711,
#  2043260.1866146987,
#  28226.707172947004,
#  459252.5181983439,
#  160332.59281489253,
#  348658.08982375264,
#  823600.6051176535,
#  654826.0208700811,
#  189913.17048871238,
#  388899.6403924385,
#  511653.6014258079,
#  2589789.3647329807,
#  1935071.5452566762,
#  1349803.3916362114,
#  119545.77520072088,
#  1573514.4438769035,
#  1839254.8149306234,
#  3119176.5602416378,
#  21318.327414546162,
#  3287141.7658213135,
#  2679436.629056262,
#  170017.74137319718,
#  227662.9213363733,
#  760052.1034725318,
#  1804502.5547404215,
#  571192.0322599178,
#  20267.4446237199,
#  1319052.444002388,
#  1011742.2470184201,
#  648128.2309539067,
#  267637.6446604021,
#  747475.6960340012,
#  1130577.0605019154,
#  2322200.1644248357,
#  4514483.438343,
#  621359.3935845001,
#  276702.6271332288,
#  748352.907727195,
#  446568.7339578206,
#  1328558.7995027257,
#  462179.7063199999,
#  2731312.8470110763,
#  3431913.5791810695,
#  1603304.9518191023,
#  547432.5873223497,
#  141096.31404958665,
#  1082772.5597792156,
#  6308.064410912804,
#  2932659.9145834344,
#  232912.20947693568,
#  601841.633973889,
#  8600.566128371283,
#  610388.0780136017,
#  278561.6100177951,
#  562564.2723757289,
#  1606872.9087074958,
#  483233.93007367384,
#  289609.5235988628,
#  1535721.1056671105,
#  346251.62852458283,
#  2265571.6699892385,
#  1326327.8349856883,
#  1750464.9575811466,
#  1659774.4445474334,
#  454631.18616883457,
#  2055828.9426488457,
#  190234.161399208,
#  770654.9827776756,
#  3886032.4960324634,
#  1303506.9391891873,
#  1115029.9894733084,
#  2657819.503122052,
#  384718.8311451068,
#  2281473.147704191,
#  2822577.8104961794,
#  94864.06815816555,
#  605259.3537239172,
#  580667.2776157204,
#  2006422.8741358053,
#  2338294.443096908,
#  979286.9848831799,
#  137442.75341761578,
#  2413699.3913939334,
#  2876010.2511466853,
#  261518.6143151857,
#  3405211.1714684255,
#  1457237.7520748973,
#  1617076.83416407,
#  2941847.3749378603,
#  121302.2148367865,
#  1403025.9106155504,
#  1253315.8566390201,
#  1352091.6232834347,
#  2417610.6003936557,
#  296556.2721101204,
#  187315.7537300745,
#  4612.388868950307,
#  3656358.7130201347,
#  1353959.464197155,
#  101532.91497403849,
#  1299387.6258030673,
#  2185083.676363338,
#  467283.5693726484,
#  105585.45369172283,
#  689936.4696957525,
#  685278.2901398689,
#  784068.2906029569,
#  232371.45001675002,
#  3243477.6420376133,
#  1265002.6225665016,
#  1359023.2166162468,
#  678944.7496185163,
#  126705.47686413117,
#  1951208.7523788884,
#  37626.948330522515,
#  1490655.5719586276,
#  917890.300893059,
#  1725397.5258731525,
#  3183501.599124998,
#  306205.6503448356,
#  1335114.9376765285]

# %%
#arvutame vahede absoluutväärtused kokku
vahe_kokku = 0
for i in vahe:
    vahe_kokku += i
vahe_kokku
# Out:
# 452910093.6389097

# %%
#kuvame keskmine vahe
keskmine_vahe = vahe_kokku // 309
print("Keskmine vahe on: " + str(keskmine_vahe))
# Out:
# Keskmine vahe on: 1465728.0

# %%
#TÄPSUSE HINDAMINE

#vaatame igat arvutatud vahet ja jagame vastavalt suuruse järgi selle gruppidesse, et näha kui täpselt ennustati streamide arvu
loendur1 = 0 
loendur2 = 0 
loendur3 = 0 
loendur4 = 0 
loendur5 = 0 
loendur6 = 0 
loendur7 = 0 
loendur8 = 0 
loendur9 = 0 
loendur10 = 0 
loendur11 = 0
loendur12 = 0
loendur13 = 0
loendur14 = 0
loendur15 = 0
loendur16 = 0
loendur17 = 0
loendur18 = 0
loendur19 = 0
loendur = 0

for i in vahe:
    if i < 10000:
        loendur1 += 1
    elif i < 100000:
        loendur2 += 1
    elif i < 200000:
        loendur3 += 1    
    elif i < 300000:
        loendur4 += 1
    elif i < 400000:
        loendur5 += 1
    elif i < 500000:
        loendur6 += 1
    elif i < 600000:
        loendur7 += 1
    elif i < 700000:
        loendur8 += 1
    elif i < 800000:
        loendur9 += 1
    elif i < 900000:
        loendur10 += 1
    elif i < 1000000:
        loendur11 += 1
    elif i < 2000000:
        loendur12 += 1
    elif i < 3000000:
        loendur13 += 1
    elif i < 4000000:
        loendur14 += 1
    elif i < 5000000:
        loendur15 += 1
    elif i < 6000000:
        loendur16 += 1
    elif i < 7000000:
        loendur17 += 1
    elif i < 8000000:
        loendur18 += 1
    elif i < 9000000:
        loendur19 += 1
    elif i >= 9000000:
        loendur += 1

#kuvame mitu ennustust olid erinevates vahemikes
print("Vahe väärtus vahemikus 0-10000: ", str(loendur1))
print("Vahe väärtus vahemikus 10000-100000: ", str(loendur2))
print("Vahe väärtus vahemikus 100000-200000: ", str(loendur3))
print("Vahe väärtus vahemikus 200000-300000: ", str(loendur4))
print("Vahe väärtus vahemikus 300000-400000: ", str(loendur5))
print("Vahe väärtus vahemikus 400000-500000: ", str(loendur6))
print("Vahe väärtus vahemikus 500000-600000: ", str(loendur7))
print("Vahe väärtus vahemikus 600000-700000: ", str(loendur8))
print("Vahe väärtus vahemikus 700000-800000: ", str(loendur9))
print("Vahe väärtus vahemikus 800000-900000: ", str(loendur10))
print("Vahe väärtus vahemikus 900000-1000000: ", str(loendur11))
print("Vahe väärtus vahemikus 1000000-2000000: ", str(loendur12))
print("Vahe väärtus vahemikus 2000000-3000000: ", str(loendur13))
print("Vahe väärtus vahemikus 3000000-4000000: ", str(loendur14))
print("Vahe väärtus vahemikus 4000000-5000000: ", str(loendur15))
print("Vahe väärtus vahemikus 5000000-6000000: ", str(loendur16))
print("Vahe väärtus vahemikus 6000000-7000000: ", str(loendur17))
print("Vahe väärtus vahemikus 7000000-8000000: ", str(loendur18))
print("Vahe väärtus vahemikus 8000000-9000000: ", str(loendur19))
print("Vahe väärtus vahemikus 9000000+: ", str(loendur))
# Out:
# Vahe väärtus vahemikus 0-10000:  6
# Vahe väärtus vahemikus 10000-100000:  10
# Vahe väärtus vahemikus 100000-200000:  20
# Vahe väärtus vahemikus 200000-300000:  18
# Vahe väärtus vahemikus 300000-400000:  11
# Vahe väärtus vahemikus 400000-500000:  16
# Vahe väärtus vahemikus 500000-600000:  14
# Vahe väärtus vahemikus 600000-700000:  15
# Vahe väärtus vahemikus 700000-800000:  18
# Vahe väärtus vahemikus 800000-900000:  10
# Vahe väärtus vahemikus 900000-1000000:  7
# Vahe väärtus vahemikus 1000000-2000000:  78
# Vahe väärtus vahemikus 2000000-3000000:  56
# Vahe väärtus vahemikus 3000000-4000000:  21
# Vahe väärtus vahemikus 4000000-5000000:  6
# Vahe väärtus vahemikus 5000000-6000000:  0
# Vahe väärtus vahemikus 6000000-7000000:  1
# Vahe väärtus vahemikus 7000000-8000000:  0
# Vahe väärtus vahemikus 8000000-9000000:  1
# Vahe väärtus vahemikus 9000000+:  1

# %%
#kuvame mitu korda oli ennustuse ja tegliku arvu vahe alla 1000
print("Vahe alla 10000 oli: ", str(loendur1))
# Out:
# Vahe alla 10000 oli:  6
